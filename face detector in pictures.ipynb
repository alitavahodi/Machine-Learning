# %%
import matplotlib.pyplot as plt
import cv2

# %%
image=cv2.imread('D:\\CB.jpg')
image=cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
plt.imshow(image)

# %%
model=cv2.CascadeClassifier('D:\\model.xml')
face=model.detectMultiScale(image)
print(face)
# Out:
# [[ 66 197  44  44]
#  [ 59  66 112 112]]

# %%
image.shape
