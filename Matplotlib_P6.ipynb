# %% [markdown]
# ## Multiple axes in 1 figure

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
fig, axes = plt.subplots(3, 2, figsize=(12, 12))

ax = axes[0][0]
x = np.linspace(0, 15, 100)
y = np.sin(x) + 0.1 * np.random.randn(len(x))
ax.plot(x, y, 'o--', label='data')

ax.set_xlabel('efiyva')
ax.set_ylabel('fayvasd')

ax.tick_params(axis='both', labelsize=10)

ax.text(0.1, 0.2, 'test', transform=ax.transAxes)

ax.legend(loc='lower right', fontsize=10)

ax = axes[1][1]

ax.hist(res, bins=20, density=True, histtype='step', label='comp1')

ax.set_xlabel('sdfava')
ax.set_ylabel('feaasd')

ax.legend()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 19
#      15 ax.legend(loc='lower right', fontsize=10)
#      17 ax = axes[1][1]
# ---> 19 ax.hist(res, bins=20, density=True, histtype='step', label='comp1')
#      21 ax.set_xlabel('sdfava')
#      22 ax.set_ylabel('feaasd')
#
# NameError: name 'res' is not defined
